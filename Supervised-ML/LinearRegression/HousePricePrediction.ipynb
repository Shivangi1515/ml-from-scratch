# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("HousePricePrediction.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0          2003          2003     VinylSd         0.0        856.0   208500.0
# 1          1976          1976     MetalSd         0.0       1262.0   181500.0
# 2          2001          2002     VinylSd         0.0        920.0   223500.0
# 3          1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4          2000          2000     VinylSd         0.0       1145.0   250000.0
# ...         ...           ...         ...         ...          ...        ...
# 2914       1970          1970     CemntBd         0.0        546.0        NaN
# 2915       1970          1970     CemntBd         0.0        546.0        NaN
# 2916       1960          1996     VinylSd         0.0       1224.0        NaN
# 2917       1992          1992     HdBoard         0.0        912.0        NaN
# 2918       1993          1994     HdBoard         0.0        996.0        NaN
#
# [2919 rows x 13 columns]

# %%
df.shape
# Out:
# (2919, 13)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0   0          60       RL     8450    Inside     1Fam            5
# 1   1          20       RL     9600       FR2     1Fam            8
# 2   2          60       RL    11250    Inside     1Fam            5
# 3   3          70       RL     9550    Corner     1Fam            5
# 4   4          60       RL    14260       FR2     1Fam            5
#
#    YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003     VinylSd         0.0        856.0   208500.0
# 1       1976          1976     MetalSd         0.0       1262.0   181500.0
# 2       2001          2002     VinylSd         0.0        920.0   223500.0
# 3       1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4       2000          2000     VinylSd         0.0       1145.0   250000.0

# %%
df.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallCond    YearBuilt  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean   1459.000000    57.137718   10168.114080     5.564577  1971.312778
# std     842.787043    42.517628    7886.996359     1.113131    30.291442
# min       0.000000    20.000000    1300.000000     1.000000  1872.000000
# 25%     729.500000    20.000000    7478.000000     5.000000  1953.500000
# 50%    1459.000000    50.000000    9453.000000     5.000000  1973.000000
# 75%    2188.500000    70.000000   11570.000000     6.000000  2001.000000
# max    2918.000000   190.000000  215245.000000     9.000000  2010.000000
#
#        YearRemodAdd   BsmtFinSF2  TotalBsmtSF      SalePrice
# count   2919.000000  2918.000000  2918.000000    1460.000000
# mean    1984.264474    49.582248  1051.777587  180921.195890
# std       20.894344   169.205611   440.766258   79442.502883
# min     1950.000000     0.000000     0.000000   34900.000000
# 25%     1965.000000     0.000000   793.000000  129975.000000
# 50%     1993.000000     0.000000   989.500000  163000.000000
# 75%     2004.000000     0.000000  1302.000000  214000.000000
# max     2010.000000  1526.000000  6110.000000  755000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            2919 non-null   int64
#  1   MSSubClass    2919 non-null   int64
#  2   MSZoning      2915 non-null   object
#  3   LotArea       2919 non-null   int64
#  4   LotConfig     2919 non-null   object
#  5   BldgType      2919 non-null   object
#  6   OverallCond   2919 non-null   int64
#  7   YearBuilt     2919 non-null   int64
#  8   YearRemodAdd  2919 non-null   int64
#  9   Exterior1st   2918 non-null   object
#  10  BsmtFinSF2    2918 non-null   float64
#  11  TotalBsmtSF   2918 non-null   float64
#  12  SalePrice     1460 non-null   float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 296.6+ KB

# %%
# Data Preprocessing - Data cleaning

# Drop Id as it doesn't contribute in price
df.drop(['Id'],
             axis=1,
             inplace=True)

# Replacing SalePrice empty values with their mean values
df['SalePrice'] = df['SalePrice'].fillna(
  df['SalePrice'].mean()) 

# Drop records with null values
df = df.dropna()

df.isnull().sum()
df.head()
# Out:
#    MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  YearBuilt  \
# 0          60       RL     8450    Inside     1Fam            5       2003
# 1          20       RL     9600       FR2     1Fam            8       1976
# 2          60       RL    11250    Inside     1Fam            5       2001
# 3          70       RL     9550    Corner     1Fam            5       1915
# 4          60       RL    14260       FR2     1Fam            5       2000
#
#    YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0          2003     VinylSd         0.0        856.0   208500.0
# 1          1976     MetalSd         0.0       1262.0   181500.0
# 2          2002     VinylSd         0.0        920.0   223500.0
# 3          1970     Wd Sdng         0.0        756.0   140000.0
# 4          2000     VinylSd         0.0       1145.0   250000.0

# %%
df
# Out:
#       MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  YearBuilt  \
# 0             60       RL     8450    Inside     1Fam            5       2003
# 1             20       RL     9600       FR2     1Fam            8       1976
# 2             60       RL    11250    Inside     1Fam            5       2001
# 3             70       RL     9550    Corner     1Fam            5       1915
# 4             60       RL    14260       FR2     1Fam            5       2000
# ...          ...      ...      ...       ...      ...          ...        ...
# 2914         160       RM     1936    Inside    Twnhs            7       1970
# 2915         160       RM     1894    Inside   TwnhsE            5       1970
# 2916          20       RL    20000    Inside     1Fam            7       1960
# 2917          85       RL    10441    Inside     1Fam            5       1992
# 2918          60       RL     9627    Inside     1Fam            5       1993
#
#       YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF     SalePrice
# 0             2003     VinylSd         0.0        856.0  208500.00000
# 1             1976     MetalSd         0.0       1262.0  181500.00000
# 2             2002     VinylSd         0.0        920.0  223500.00000
# 3             1970     Wd Sdng         0.0        756.0  140000.00000
# 4             2000     VinylSd         0.0       1145.0  250000.00000
# ...            ...         ...         ...          ...           ...
# 2914          1970     CemntBd         0.0        546.0  180921.19589
# 2915          1970     CemntBd         0.0        546.0  180921.19589
# 2916          1996     VinylSd         0.0       1224.0  180921.19589
# 2917          1992     HdBoard         0.0        912.0  180921.19589
# 2918          1994     HdBoard         0.0        996.0  180921.19589
#
# [2913 rows x 12 columns]

# %%
#Data-preprocessing--Encoding

cols=['MSZoning','LotConfig','BldgType','Exterior1st']
df=pd.get_dummies(df,columns=cols,drop_first=True)

# %%
#Train test Split
from sklearn.model_selection import train_test_split
X=df.drop(['SalePrice'],axis=1)
Y=df['SalePrice']

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 1453          20    17217            5       2006          2006         0.0
# 2021          20    19508            5       1974          1974         0.0
# 188           90     7018            5       1979          1979         0.0
# 1273          80    11512            7       1959          2006         0.0
# 1960          20     7560            5       1971          1971       613.0
# ...          ...      ...          ...        ...           ...         ...
# 763           60     9430            5       1999          1999         0.0
# 835           20     9600            7       1950          1995         0.0
# 1653         160     2308            5       1976          1976         0.0
# 2612          20    11625            7       1983          1983         0.0
# 2737          90     8917            5       1967          1967         0.0
#
#       TotalBsmtSF  MSZoning_FV  MSZoning_RH  MSZoning_RL  ...  \
# 1453       1140.0        False        False         True  ...
# 2021       1430.0        False        False         True  ...
# 188        1086.0        False        False         True  ...
# 1273       1019.0        False        False         True  ...
# 1960        864.0        False        False         True  ...
# ...           ...          ...          ...          ...  ...
# 763        1252.0        False        False         True  ...
# 835        1067.0        False        False         True  ...
# 1653        804.0        False        False         True  ...
# 2612        816.0        False        False         True  ...
# 2737       1584.0        False        False         True  ...
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 1453                False                False                False
# 2021                False                 True                False
# 188                 False                False                False
# 1273                False                False                False
# 1960                False                False                False
# ...                   ...                  ...                  ...
# 763                 False                False                False
# 835                 False                False                False
# 1653                False                False                False
# 2612                False                 True                False
# 2737                False                False                False
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 1453                False                False              False
# 2021                False                False              False
# 188                 False                 True              False
# 1273                False                 True              False
# 1960                 True                False              False
# ...                   ...                  ...                ...
# 763                 False                False              False
# 835                 False                False              False
# 1653                False                 True              False
# 2612                False                False              False
# 2737                False                 True              False
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 1453               False                 True                False
# 2021               False                False                False
# 188                False                False                False
# 1273               False                False                False
# 1960               False                False                False
# ...                  ...                  ...                  ...
# 763                False                 True                False
# 835                False                 True                False
# 1653               False                False                False
# 2612               False                False                False
# 2737               False                False                False
#
#       Exterior1st_WdShing
# 1453                False
# 2021                False
# 188                 False
# 1273                False
# 1960                False
# ...                   ...
# 763                 False
# 835                 False
# 1653                False
# 2612                False
# 2737                False
#
# [2330 rows x 33 columns]

# %%
y_train
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 1728          60    10274            7       1986          1986         0.0
# 2689          60    13162            5       2006          2006         0.0
# 1151          20    17755            4       1959          1959         0.0
# 2762          20    10800            6       1961          1992         0.0
# 1180          60    11170            5       1990          1991         0.0
# ...          ...      ...          ...        ...           ...         ...
# 1840          90    10547            5       1978          1978         0.0
# 776           20    11210            5       2005          2006         0.0
# 1519          20     8050            5       1959          1959       162.0
# 1359          20    16737            5       2004          2005         0.0
# 563           50    21780            7       1918          1950         0.0
#
#       TotalBsmtSF  MSZoning_FV  MSZoning_RH  MSZoning_RL  ...  \
# 1728        676.0        False        False         True  ...
# 2689       2036.0         True        False        False  ...
# 1151       1466.0        False        False         True  ...
# 2762       1313.0        False        False         True  ...
# 1180       1216.0        False        False         True  ...
# ...           ...          ...          ...          ...  ...
# 1840       1152.0        False        False         True  ...
# 776        1614.0        False        False         True  ...
# 1519       1143.0        False        False         True  ...
# 1359       1980.0        False        False         True  ...
# 563        1163.0        False        False         True  ...
#
#       Exterior1st_CemntBd  Exterior1st_HdBoard  Exterior1st_ImStucc  \
# 1728                False                False                False
# 2689                False                False                False
# 1151                False                 True                False
# 2762                False                 True                False
# 1180                False                False                False
# ...                   ...                  ...                  ...
# 1840                False                False                False
# 776                 False                False                False
# 1519                False                False                False
# 1359                False                False                False
# 563                 False                False                False
#
#       Exterior1st_MetalSd  Exterior1st_Plywood  Exterior1st_Stone  \
# 1728                False                False              False
# 2689                False                False              False
# 1151                False                False              False
# 2762                False                False              False
# 1180                 True                False              False
# ...                   ...                  ...                ...
# 1840                False                 True              False
# 776                 False                False              False
# 1519                 True                False              False
# 1359                False                False              False
# 563                 False                False              False
#
#       Exterior1st_Stucco  Exterior1st_VinylSd  Exterior1st_Wd Sdng  \
# 1728               False                 True                False
# 2689               False                 True                False
# 1151               False                False                False
# 2762               False                False                False
# 1180               False                False                False
# ...                  ...                  ...                  ...
# 1840               False                False                False
# 776                False                 True                False
# 1519               False                False                False
# 1359               False                 True                False
# 563                False                False                 True
#
#       Exterior1st_WdShing
# 1728                False
# 2689                False
# 1151                False
# 2762                False
# 1180                False
# ...                   ...
# 1840                False
# 776                 False
# 1519                False
# 1359                False
# 563                 False
#
# [583 rows x 33 columns]

# %%
# Train Linear Regression Model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Model Evaluation
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

y_pred=model.predict(X_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print(mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.37414217961383023
# MAE 30829.93666432242
# RMSE 41138.55870230181
# 30829.93666432242
